# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('ANZ synthesised transaction dataset.xlsx')
d=df.copy()

# %%
d.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
# status               12043 non-null object
# card_present_flag    7717 non-null float64
# bpay_biller_code     885 non-null object
# account              12043 non-null object
# currency             12043 non-null object
# long_lat             12043 non-null object
# txn_description      12043 non-null object
# merchant_id          7717 non-null object
# merchant_code        883 non-null float64
# first_name           12043 non-null object
# balance              12043 non-null float64
# date                 12043 non-null datetime64[ns]
# gender               12043 non-null object
# age                  12043 non-null int64
# merchant_suburb      7717 non-null object
# merchant_state       7717 non-null object
# extraction           12043 non-null object
# amount               12043 non-null float64
# transaction_id       12043 non-null object
# ...

# %%
plt.style.use('seaborn-whitegrid')
d.hist(bins=20,figsize=(14,10))
plt.show()

# %%
d.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount
# count  12043.000000
# mean     187.933588
# std      592.599934
# min        0.100000
# 25%       16.000000
# 50%       29.000000
# 75%       53.655000
# max     8835.980000

# %%
d.isnull().sum()
# Out:
# status                   0
# card_present_flag     4326
# bpay_biller_code     11158
# account                  0
# currency                 0
# long_lat                 0
# txn_description          0
# merchant_id           4326
# merchant_code        11160
# first_name               0
# balance                  0
# date                     0
# gender                   0
# age                      0
# merchant_suburb       4326
# merchant_state        4326
# extraction               0
# amount                   0
# transaction_id           0
# country                  0
# customer_id              0
# merchant_long_lat     4326
# movement                 0
# dtype: int64

# %%
plt.figure(figsize=(6,5))
cor=d.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Reds)
plt.show()

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
# status               12043 non-null object
# card_present_flag    7717 non-null float64
# bpay_biller_code     885 non-null object
# account              12043 non-null object
# currency             12043 non-null object
# long_lat             12043 non-null object
# txn_description      12043 non-null object
# merchant_id          7717 non-null object
# merchant_code        883 non-null float64
# first_name           12043 non-null object
# balance              12043 non-null float64
# date                 12043 non-null datetime64[ns]
# gender               12043 non-null object
# age                  12043 non-null int64
# merchant_suburb      7717 non-null object
# merchant_state       7717 non-null object
# extraction           12043 non-null object
# amount               12043 non-null float64
# transaction_id       12043 non-null object
# ...

# %%
plt.style.use('seaborn-whitegrid')
d.hist(bins=20,figsize=(14,10))
plt.show()

# %%
d['balance'].plot.box(figsize=(14,10))

# %%
sns.boxplot(y='amount', x='movement', 
                 data=d, 
                 palette="colorblind",
                 hue='month')

# %%
d['year'] = pd.DatetimeIndex(d['date']).year
d['month'] = pd.DatetimeIndex(d['date']).month
d['day'] = pd.DatetimeIndex(d['date']).day
d['time']=list(map(lambda x:x.split('T')[1],d['extraction']))
d['hour']=list(map(lambda x:int(x.split(':')[0]),d['time']))

# %%
d.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...                    transaction_id    country  \
# ...

# %%
d['extraction'][0].split('T')
# Out:
# ['2018-08-01', '01:01:15.000+0000']

# %%
d['time']=list(map(lambda x:x.split('T')[1],d['extraction']))

# %%
d.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  amount                    transaction_id  \
# ...

# %%
d['hour']=list(map(lambda x:int(x.split(':')[0]),d['time']))

# %%
d.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...                    transaction_id    country  \
# ...

# %%
d.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount     year         month           day          hour
# count  12043.000000  12043.0  12043.000000  12043.000000  12043.000000
# mean     187.933588   2018.0      9.011957     15.862908     13.268621
# std      592.599934      0.0      0.816511      8.899598      5.777284
# ...

# %%
d['hour'].value_counts()
# Out:
# 9     1106
# 11     941
# 17     815
# 14     757
# 21     741
# 15     728
# 10     615
# 20     598
# 13     558
# 19     548
# 8      547
# 12     543
# 16     516
# 22     458
# 23     426
# 18     383
# 4      309
# 7      266
# 6      249
# 1      214
# 2      212
# 5      209
# 3      196
# 0      108
# Name: hour, dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 28 columns):
# status               12043 non-null object
# card_present_flag    7717 non-null float64
# bpay_biller_code     885 non-null object
# account              12043 non-null object
# currency             12043 non-null object
# long_lat             12043 non-null object
# txn_description      12043 non-null object
# merchant_id          7717 non-null object
# merchant_code        883 non-null float64
# first_name           12043 non-null object
# balance              12043 non-null float64
# date                 12043 non-null datetime64[ns]
# gender               12043 non-null object
# age                  12043 non-null int64
# merchant_suburb      7717 non-null object
# merchant_state       7717 non-null object
# extraction           12043 non-null object
# amount               12043 non-null float64
# transaction_id       12043 non-null object
# ...

# %%
plt.style.use('seaborn-whitegrid')
d.hist(bins=20,figsize=(14,10))
plt.show()

# %%
d['month'].value_counts()
# Out:
# 10    4087
# 9     4013
# 8     3943
# Name: month, dtype: int64

# %%
d['country'].value_counts()
# Out:
# Australia    12043
# Name: country, dtype: int64

# %%
d['merchant_state'].value_counts()
# Out:
# NSW    2169
# VIC    2131
# QLD    1556
# WA     1100
# SA      415
# NT      205
# ACT      73
# TAS      68
# Name: merchant_state, dtype: int64

# %%
d['merchant_suburb'].value_counts()
# Out:
# Melbourne         255
# Sydney            233
# Southport          82
# Brisbane City      79
# Chatswood          55
#                  ...
# Greenvale           1
# Enoggera            1
# Narrabeen           1
# Beaumont Hills      1
# Ballan              1
# Name: merchant_suburb, Length: 1609, dtype: int64

# %%
d['movement'].value_counts()
# Out:
# debit     11160
# credit      883
# Name: movement, dtype: int64

# %%
d['status'].value_counts()
# Out:
# authorized    7717
# posted        4326
# Name: status, dtype: int64

# %%
d['card_present_flag'].value_counts()
# Out:
# 1.0    6194
# 0.0    1523
# Name: card_present_flag, dtype: int64

# %%
d['txn_description'].value_counts()
# Out:
# SALES-POS     3934
# POS           3783
# PAYMENT       2600
# PAY/SALARY     883
# INTER BANK     742
# PHONE BANK     101
# Name: txn_description, dtype: int64

# %%
pd.crosstab(d['movement'],d['txn_description'])
# Out:
# txn_description  INTER BANK  PAY/SALARY  PAYMENT  PHONE BANK   POS  SALES-POS
# movement
# credit                    0         883        0           0     0          0
# debit                   742           0     2600         101  3783       3934

# %%
pd.crosstab(d['movement'],d['merchant_state'])
# Out:
# merchant_state  ACT   NSW   NT   QLD   SA  TAS   VIC    WA
# movement
# debit            73  2169  205  1556  415   68  2131  1100

# %%
sns.pairplot(d)

# %%
d['month'].value_counts()
# Out:
# 10    4087
# 9     4013
# 8     3943
# Name: month, dtype: int64

# %%
(4087+4013+3943)/3
# Out:
# 4014.3333333333335

# %%
d['hour'].value_counts().plot(kind='bar',figsize=(14,10))

# %%
d['merchant_state'].value_counts().plot(kind='bar',figsize=(14,10))

# %%
d['amount']
# Out:
# 0        16.25
# 1        14.19
# 2         6.42
# 3        40.90
# 4         3.25
#          ...
# 12038     9.79
# 12039    63.87
# 12040    43.96
# 12041    30.77
# 12042    22.36
# Name: amount, Length: 12043, dtype: float64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.barplot(x='merchant_state',y='amount',data=d,ax=ax)

# %%
sns.barplot(x='month',y='amount',data=d)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15.7, 9.27)
sns.barplot(x='day',y='amount',data=d)

# %%
d['merchant_code'].value_counts()
# Out:
# 0.0    883
# Name: merchant_code, dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 28 columns):
# status               12043 non-null object
# card_present_flag    7717 non-null float64
# bpay_biller_code     885 non-null object
# account              12043 non-null object
# currency             12043 non-null object
# long_lat             12043 non-null object
# txn_description      12043 non-null object
# merchant_id          7717 non-null object
# merchant_code        883 non-null float64
# first_name           12043 non-null object
# balance              12043 non-null float64
# date                 12043 non-null datetime64[ns]
# gender               12043 non-null object
# age                  12043 non-null int64
# merchant_suburb      7717 non-null object
# merchant_state       7717 non-null object
# extraction           12043 non-null object
# amount               12043 non-null float64
# transaction_id       12043 non-null object
# ...

# %%
ds=d[d['txn_description']=='PAY/SALARY']
ds
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 50     posted                NaN                0   ACC-588564840      AUD
# 61     posted                NaN                0  ACC-1650504218      AUD
# 64     posted                NaN                0  ACC-3326339947      AUD
# 68     posted                NaN                0  ACC-3541460373      AUD
# 70     posted                NaN                0  ACC-2776252858      AUD
# ...       ...                ...              ...             ...      ...
# 11995  posted                NaN                0  ACC-1973887809      AUD
# 12000  posted                NaN                0   ACC-819621312      AUD
# 12001  posted                NaN                0  ACC-2920611728      AUD
# 12003  posted                NaN                0  ACC-1799207998      AUD
# 12004  posted                NaN                0  ACC-2171593283      AUD
#
# ...

# %%
ds['customer_id'].value_counts()
# Out:
# CUS-164374203     14
# CUS-326006476     14
# CUS-1388323263    14
# CUS-2500783281    14
# CUS-1271030853    14
#                   ..
# CUS-423725039      3
# CUS-497688347      2
# CUS-1739931018     2
# CUS-51506836       2
# CUS-2178051368     2
# Name: customer_id, Length: 100, dtype: int64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15.7, 9.27)
sns.barplot(x='customer_id',y='amount',data=ds)

# %%
da=ds[['customer_id','amount']]

# %%
da.groupby(['customer_id']).sum()
# Out:
#                   amount
# customer_id
# CUS-1005756958  12616.11
# CUS-1117979751  25050.55
# CUS-1140341822  11499.06
# CUS-1147642491  22248.07
# CUS-1196156254  27326.11
# ...                  ...
# CUS-72755508     8703.84
# CUS-809013380   13481.91
# CUS-860700529   10851.72
# CUS-880898248    8603.88
# CUS-883482547   27842.22
#
# [100 rows x 1 columns]

# %%
ds.isnull().sum()
# Out:
# status                 0
# card_present_flag    883
# bpay_biller_code       0
# account                0
# currency               0
# long_lat               0
# txn_description        0
# merchant_id          883
# merchant_code          0
# first_name             0
# balance                0
# date                   0
# gender                 0
# age                    0
# merchant_suburb      883
# merchant_state       883
# extraction             0
# amount                 0
# transaction_id         0
# country                0
# customer_id            0
# merchant_long_lat    883
# movement               0
# year                   0
# month                  0
# day                    0
# time                   0
# hour                   0
# dtype: int64

# %%
plt.figure(figsize=(12,10))
cor=ds.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Reds)
plt.show()

# %%
cor_target=abs(cor['amount'])
relevant_features=cor_target[cor_target>-0.00005]
print(relevant_features,'\n')
# Out:
# balance    0.287501
# age        0.138594
# amount     1.000000
# month      0.014061
# day        0.005170
# hour       0.002465
# Name: amount, dtype: float64

# %%
ds_a=ds[['first_name','balance','gender','age','amount','customer_id','month','day','hour']]

# %%
ds_a=ds_a.replace({'gender':{'M':0,'F':1}})

# %%
ds_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 883 entries, 50 to 12004
# Data columns (total 9 columns):
# first_name     883 non-null object
# balance        883 non-null float64
# gender         883 non-null int64
# age            883 non-null int64
# amount         883 non-null float64
# customer_id    883 non-null object
# month          883 non-null int64
# day            883 non-null int64
# hour           883 non-null int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 69.0+ KB

# %%
ds_a_c=ds_a[['first_name','customer_id']]

# %%
ds_a.drop(['first_name','customer_id'],inplace=True,axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
ds_ec=ds_a_c.apply(encoder.fit_transform)

# %%
ds_a=pd.concat([ds_a,ds_ec],axis=1,sort=False)
ds_a.head()
# Out:
#     balance  gender  age   amount  month  day  hour  first_name  customer_id
# 50  8342.11       0   23  3903.95      8    1    11          30           13
# 61  2040.58       1   23  1626.48      8    1    12          48           47
# 64  3158.51       0   22   983.36      8    1    12          26           70
# 68  2517.66       0   24  1408.08      8    1    13          33           12
# 70  2271.79       1   43  1068.04      8    1    13          41           83

# %%
plt.figure(figsize=(12,10))
cor=ds_a.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Reds)
plt.show()

# %%
Y=ds_a['amount']
X=ds_a.drop(['amount'],axis=1)

# %%
X.head()
# Out:
#     balance  gender  age  month  day  hour  first_name  customer_id
# 50  8342.11       0   23      8    1    11          30           13
# 61  2040.58       1   23      8    1    12          48           47
# 64  3158.51       0   22      8    1    12          26           70
# 68  2517.66       0   24      8    1    13          33           12
# 70  2271.79       1   43      8    1    13          41           83

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# print the intercept
print(lm.intercept_)
# Out:
# 2831.2144690577115

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#              Coefficient
# balance         0.014304
# gender       -375.715178
# age           -20.496066
# month          -5.914406
# day             3.126893
# hour           -4.709254
# first_name     -1.393152
# customer_id    -3.931336

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 723.2402711065388
# MSE: 922322.5732908924
# RMSE: 960.3762665179166

# %%
Y = pd.get_dummies(Y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         2
#            9       0.00      0.00      0.00         0
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         5
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         5
#           14       1.00      1.00      1.00         3
#           15       1.00      1.00      1.00         4
# ...
